# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
# Load the Fashion MNIST dataset
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
# Preprocess the data
train_images = train_images.reshape((train_images.shape[0], 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1)).astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Define the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# C:\Users\Nishigandha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
import time

start_time=time.time()

# Train the model
model.fit(train_images, train_labels, epochs=15,batch_size=64, validation_split=0.2)

train_time=time.time()-start_time

print("Training time: ", train_time)
# Out:
# Epoch 1/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - accuracy: 0.6901 - loss: 0.8399 - val_accuracy: 0.8618 - val_loss: 0.3913
# Epoch 2/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.8642 - loss: 0.3695 - val_accuracy: 0.8803 - val_loss: 0.3294
# Epoch 3/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.8891 - loss: 0.3066 - val_accuracy: 0.8886 - val_loss: 0.3011
# Epoch 4/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9008 - loss: 0.2738 - val_accuracy: 0.8896 - val_loss: 0.3051
# Epoch 5/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9066 - loss: 0.2530 - val_accuracy: 0.8953 - val_loss: 0.2860
# Epoch 6/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9149 - loss: 0.2320 - val_accuracy: 0.9055 - val_loss: 0.2648
# Epoch 7/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9281 - loss: 0.2020 - val_accuracy: 0.8993 - val_loss: 0.2743
# Epoch 8/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9295 - loss: 0.1890 - val_accuracy: 0.9100 - val_loss: 0.2587
# Epoch 9/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9353 - loss: 0.1800 - val_accuracy: 0.9106 - val_loss: 0.2530
# Epoch 10/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9392 - loss: 0.1647 - val_accuracy: 0.9120 - val_loss: 0.2622
# Epoch 11/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9452 - loss: 0.1492 - val_accuracy: 0.9094 - val_loss: 0.2678
# Epoch 12/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9526 - loss: 0.1368 - val_accuracy: 0.9114 - val_loss: 0.2608
# Epoch 13/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9537 - loss: 0.1287 - val_accuracy: 0.9139 - val_loss: 0.2638
# Epoch 14/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9585 - loss: 0.1124 - val_accuracy: 0.9101 - val_loss: 0.2862
# Epoch 15/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9617 - loss: 0.1043 - val_accuracy: 0.9103 - val_loss: 0.3022
# Training time:  247.36454129219055

# %%
loss, acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9014 - loss: 0.3351

# %%
# Select random images from the test set
num_samples = 5
random_indices = np.random.choice(len(test_images), num_samples, replace=False)
sample_images = test_images[random_indices]
sample_labels = test_labels[random_indices]

# Make predictions on the sample images
predictions = model.predict(sample_images)
predicted_labels = np.argmax(predictions, axis=1)

# Define class labels
class_labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Show images with their predicted and true labels
plt.figure(figsize=(10, 6))
for i in range(num_samples):
    plt.subplot(1, num_samples, i + 1)
    plt.imshow(sample_images[i].reshape(28, 28), cmap='gray')
    plt.title(f"True: {class_labels[np.argmax(sample_labels[i])]} \nPredicted: {class_labels[predicted_labels[i]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
import cv2

def preprocess_image(image_path):
  """
  Preprocesses a fashion image with black background and white foreground.

  Args:
      image_path: Path to the image file.

  Returns:
      A NumPy array representing the preprocessed image.
  """
  # Read the image
  image = cv2.imread(image_path)
  # Convert BGR (OpenCV default) to RGB (Matplotlib default)
  image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  plt.title("Original Image")
  # Display the image
  plt.imshow(image_rgb)
  # plt.axis('off')  # Turn off axis labels
  plt.show()


  # Load the image from the file path in grayscale mode
  img = load_img(image_path, color_mode="grayscale", target_size=(28, 28))
  # Convert the image to a NumPy array
  img_array = img_to_array(img)
  # Invert the grayscale values (black -> white, white -> black)
  img_array = 255 - img_array
  # Show grayscale image
  plt.title("Preprocessed Grayscale Image")
  plt.imshow(img_array, cmap='gray')
  # Reshape the image array to add a dimension for the color channel (even though it's grayscale)
  img_array = img_array.reshape((1, 28, 28, 1))

  # Normalize the pixel values to be between 0 and 1
  return img_array / 255.0

# %%
#predicting the class for real time images
preprocessed_image = preprocess_image("fashion/Tshirt.jpg")
start_time=time.time()
predictions = model.predict(preprocessed_image)
pred_time= time.time()-start_time
print(predictions)
print("Predicted Class: ",class_labels[np.argmax(predictions)])
print("Prediction Time: ", pred_time)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# [[9.95678484e-01 2.51460338e-13 1.44769865e-05 1.00315267e-08
#   5.84941802e-07 6.13423090e-09 4.30644257e-03 1.23501808e-14
#   4.75409878e-10 3.11647069e-10]]
# Predicted Class:  T-shirt/top
# Prediction Time:  0.5030665397644043

# %%
#predicting the class for real time images
preprocessed_image = preprocess_image("fashion/handbag.jpg")
start_time=time.time()
predictions = model.predict(preprocessed_image)
pred_time= time.time()-start_time
print(predictions)
print("Predicted Class: ",class_labels[np.argmax(predictions)])
print("Prediction Time: ", pred_time)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# [[2.4477612e-12 1.2951123e-17 4.8721425e-16 9.7945020e-17 5.4537524e-16
#   2.4487072e-17 2.8497285e-12 1.6966564e-16 1.0000000e+00 6.1429868e-16]]
# Predicted Class:  Bag
# Prediction Time:  0.2041020393371582

# %%
#predicting the class for real time images
preprocessed_image = preprocess_image("fashion/dress1.jpg")
start_time=time.time()
predictions = model.predict(preprocessed_image)
pred_time= time.time()-start_time
print(predictions)
print("Predicted Class: ",class_labels[np.argmax(predictions)])
print("Prediction Time: ", pred_time)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# [[1.2135650e-02 1.7537801e-06 1.3225898e-04 8.9363164e-01 3.2313128e-05
#   8.0552958e-08 9.3700804e-02 3.3289627e-08 3.6379081e-04 1.6843082e-06]]
# Predicted Class:  Dress
# Prediction Time:  0.18940520286560059

# %%
#predicting the class for real time images
preprocessed_image = preprocess_image("fashion/sandal.jpg")
start_time=time.time()
predictions = model.predict(preprocessed_image)
pred_time= time.time()-start_time
print(predictions)
print("Predicted Class: ",class_labels[np.argmax(predictions)])
print("Prediction Time: ", pred_time)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# [[2.8433228e-10 9.3046959e-12 7.3272305e-11 3.5589272e-13 4.7339655e-15
#   9.9999547e-01 1.9167296e-12 6.4356101e-07 1.1975214e-10 3.9620008e-06]]
# Predicted Class:  Sandal
# Prediction Time:  0.18848633766174316

# %%
#predicting the class for real time images
preprocessed_image = preprocess_image("fashion/ankleboot.jpeg")
start_time=time.time()
predictions = model.predict(preprocessed_image)
pred_time= time.time()-start_time
print(predictions)
print("Predicted Class: ",class_labels[np.argmax(predictions)])
print("Prediction Time: ", pred_time)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [[2.2822201e-08 4.4561626e-09 1.3361492e-09 2.2238771e-09 2.6831509e-10
#   5.2478950e-05 9.1571833e-10 5.2038995e-03 3.7085888e-07 9.9474323e-01]]
# Predicted Class:  Ankle boot
# Prediction Time:  0.2201862335205078

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from ipywidgets import FileUpload
from IPython.display import display
import cv2
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Function to preprocess an uploaded image
def preprocess_uploaded_image(change):
    # Get the uploaded image content
    uploaded_image = change['new'][0]
    content = uploaded_image['content']
    
    # Convert the content to a NumPy array
    nparr = np.frombuffer(content, np.uint8)
    
    # Read the image
    image = cv2.imdecode(nparr, cv2.IMREAD_GRAYSCALE)
    
    # Resize the image to 28x28
    resized_image = cv2.resize(image, (28, 28))
    
    # Invert the grayscale values (black -> white, white -> black)
    inverted_image = 255 - resized_image
    
    # Reshape the image array to add a dimension for the color channel (even though it's grayscale)
    img_array = inverted_image.reshape((1, 28, 28, 1))

    # Normalize the pixel values to be between 0 and 1
    preprocessed_image = img_array / 255.0
    
    # Make predictions on the preprocessed image
    predictions = model.predict(preprocessed_image)
    
    # Get the predicted class label
    predicted_class = class_labels[np.argmax(predictions)]
    
    # Display the preprocessed image and the predicted class label
    plt.imshow(resized_image, cmap='gray')
    plt.title(f"Predicted Class: {predicted_class}")
    plt.axis('off')
    plt.show()

# Create a FileUpload widget
uploader = FileUpload(accept='.jpg,.jpeg,.png')

# Display the FileUpload widget
display(uploader)

# Register the preprocess function to be called when a file is uploaded
uploader.observe(preprocess_uploaded_image, names='value')
# Out:
# FileUpload(value=(), accept='.jpg,.jpeg,.png', description='Upload')
